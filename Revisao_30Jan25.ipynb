# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardoefamilia/CollectionsSet/blob/master/Revisao_30Jan25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %%
base = pd.read_csv("https://raw.githubusercontent.com/andfranca/proadi-sus-ciencia-de-dados-ia/refs/heads/main/bases/banco-laboratorio.csv",sep=',')

# %%
base.describe()
# Out:
#        IDCOLABORADOR        IDADE          CEP  NIVELEDUCACAO   RENDAMENSAL  \
# count    1470.000000  1470.000000  1426.000000    1470.000000   1470.000000
# mean     1024.865306    36.923810     9.140252       2.912925  14313.103401
# std       602.024335     9.135373     8.065954       1.024165   7117.786044
# min         1.000000    18.000000     1.000000       1.000000   2094.000000
# 25%       491.250000    30.000000     2.000000       2.000000   8047.000000
# 50%      1020.500000    36.000000     7.000000       3.000000  14235.500000
# 75%      1555.750000    43.000000    14.000000       4.000000  20461.500000
# max      2068.000000    60.000000    29.000000       5.000000  26999.000000
#
#        ANONAEMPRESA  ANOSMESMAPOSICAO  ANOSDESDEULTIMAPROMOCAO
# count   1470.000000       1470.000000              1470.000000
# mean       7.008163          4.229252                 2.187755
# std        6.126525          3.623137                 3.222430
# ...

# %%
base.head()
# Out:
#    IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL    GENERO            NOME  \
# 0              1     41           Sim    Solteiro  Feminino  Maria da Silva
# 1              5     33           Nao      Casado  Feminino    Ana Oliveira
# 2             10     59           Nao      Casado  Feminino  Juliana Santos
# 3             15     29           Nao    Solteiro  Feminino  Fernanda Costa
# 4             20     29           Nao  Divorciado  Feminino    Beatriz Lima
#
#        SETOR                   CARGO   CEP  NIVELEDUCACAO          FORMACAO  \
# 0  Alimentos                 Auditor   1.0              2  Ciencias Sociais
# 1      Saude             Pesquisador   3.0              4  Ciencias Sociais
# 2      Saude  Tecnico de Laboratorio   3.0              3          Medicina
# 3      Saude  Tecnico de Laboratorio   NaN              2  Ciencias Sociais
# 4      Saude   Diretor de Manufatura  21.0              4  Ciencias Sociais
#
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   IDCOLABORADOR            1470 non-null   int64
#  1   IDADE                    1470 non-null   int64
#  2   INSATISTFEITO            1470 non-null   object
#  3   STATUSCIVIL              1470 non-null   object
#  4   GENERO                   1470 non-null   object
#  5   NOME                     1470 non-null   object
#  6   SETOR                    1470 non-null   object
#  7   CARGO                    1470 non-null   object
#  8   CEP                      1426 non-null   float64
#  9   NIVELEDUCACAO            1470 non-null   int64
#  10  FORMACAO                 1470 non-null   object
#  11  RENDAMENSAL              1470 non-null   int64
#  12  DESCONTOULTIMAFATURA     1470 non-null   object
#  13  ANONAEMPRESA             1470 non-null   int64
# ...

# %%
base.isna().sum()
# Out:
# IDCOLABORADOR               0
# IDADE                       0
# INSATISTFEITO               0
# STATUSCIVIL                 0
# GENERO                      0
# NOME                        0
# SETOR                       0
# CARGO                       0
# CEP                        44
# NIVELEDUCACAO               0
# FORMACAO                    0
# RENDAMENSAL                 0
# DESCONTOULTIMAFATURA        0
# ANONAEMPRESA                0
# ANOSMESMAPOSICAO            0
# ANOSDESDEULTIMAPROMOCAO     0
# dtype: int64

# %%
#subset - selecionar pedaços da base de dados para work
base['IDADE']
# Out:
# 0       41
# 1       33
# 2       59
# 3       29
# 4       29
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: IDADE, Length: 1470, dtype: int64

# %%
#subset de mais de uma coluna
base[['IDADE','STATUSCIVIL']]
# Out:
#       IDADE STATUSCIVIL
# 0        41    Solteiro
# 1        33      Casado
# 2        59      Casado
# 3        29    Solteiro
# 4        29  Divorciado
# ...     ...         ...
# 1465     36      Casado
# 1466     39      Casado
# 1467     27      Casado
# 1468     49      Casado
# 1469     34      Casado
#
# [1470 rows x 2 columns]

# %%
#working utilizando operadores
base[(base['IDADE']>30)&
     (base['STATUSCIVIL']=='Casado')&
     (base['INSATISTFEITO']=='Sim')
     ]
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 18               58     41           Sim      Casado   Feminino
# 46              161     56           Sim      Casado   Feminino
# 48              165     58           Sim      Casado   Feminino
# 52              175     31           Sim      Casado   Feminino
# 96              328     33           Sim      Casado   Feminino
# 126             445     39           Sim      Casado   Feminino
# 203             684     45           Sim      Casado   Feminino
# 247             840     49           Sim      Casado   Feminino
# 306            1033     37           Sim      Casado   Feminino
# 308            1038     52           Sim      Casado   Feminino
# 380            1295     44           Sim      Casado   Feminino
# 399            1360     58           Sim      Casado   Feminino
# 408            1380     35           Sim      Casado   Feminino
# 434            1467     34           Sim      Casado   Feminino
# ...

# %%
#filtrando apresentando colunas desejadas
base_filtrada = base[(base['IDADE']>30)&
     (base['STATUSCIVIL']=='Casado')&
     (base['INSATISTFEITO']=='Sim')
     ]

base_filtrada
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 18               58     41           Sim      Casado   Feminino
# 46              161     56           Sim      Casado   Feminino
# 48              165     58           Sim      Casado   Feminino
# 52              175     31           Sim      Casado   Feminino
# 96              328     33           Sim      Casado   Feminino
# 126             445     39           Sim      Casado   Feminino
# 203             684     45           Sim      Casado   Feminino
# 247             840     49           Sim      Casado   Feminino
# 306            1033     37           Sim      Casado   Feminino
# 308            1038     52           Sim      Casado   Feminino
# 380            1295     44           Sim      Casado   Feminino
# 399            1360     58           Sim      Casado   Feminino
# 408            1380     35           Sim      Casado   Feminino
# 434            1467     34           Sim      Casado   Feminino
# ...

# %%
base_filtrada[['IDADE','STATUSCIVIL','STATUSCIVIL']]
# Out:
#       IDADE STATUSCIVIL STATUSCIVIL
# 18       41      Casado      Casado
# 46       56      Casado      Casado
# 48       58      Casado      Casado
# 52       31      Casado      Casado
# 96       33      Casado      Casado
# 126      39      Casado      Casado
# 203      45      Casado      Casado
# 247      49      Casado      Casado
# 306      37      Casado      Casado
# 308      52      Casado      Casado
# 380      44      Casado      Casado
# 399      58      Casado      Casado
# 408      35      Casado      Casado
# 434      34      Casado      Casado
# 454      53      Casado      Casado
# 494      48      Casado      Casado
# 523      46      Casado      Casado
# 539      46      Casado      Casado
# 609      39      Casado      Casado
# 611      50      Casado      Casado
# 629      36      Casado      Casado
# 665      31      Casado      Casado
# 700      35      Casado      Casado
# 710      38      Casado      Casado
# 714      32      Casado      Casado
# ...

# %%
#DELETAR UMA VARIÁVEL (OBJETO)
#del base (por exemplo)

# %%
#Resetar o índice
base_filtrada.reset_index(inplace=True,drop=True)
# Out:
#     IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0              58     41           Sim      Casado   Feminino
# 1             161     56           Sim      Casado   Feminino
# 2             165     58           Sim      Casado   Feminino
# 3             175     31           Sim      Casado   Feminino
# 4             328     33           Sim      Casado   Feminino
# 5             445     39           Sim      Casado   Feminino
# 6             684     45           Sim      Casado   Feminino
# 7             840     49           Sim      Casado   Feminino
# 8            1033     37           Sim      Casado   Feminino
# 9            1038     52           Sim      Casado   Feminino
# 10           1295     44           Sim      Casado   Feminino
# 11           1360     58           Sim      Casado   Feminino
# 12           1380     35           Sim      Casado   Feminino
# 13           1467     34           Sim      Casado   Feminino
# ...

# %%
#Criando um novo arquivo csv clonado da base filtrada, por exemplo
base_filtrada.to_csv('base_filtrada.csv',index=False,sep=";", decimal=",")

# %%
#Criando uma nova coluna na base, exemplo
base_filtrada['coluna_nova'] = 0
# Out:
# <ipython-input-29-25a17a46043d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_filtrada['coluna_nova'] = 0

# %%
base_filtrada
# Out:
#     IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0              58     41           Sim      Casado   Feminino
# 1             161     56           Sim      Casado   Feminino
# 2             165     58           Sim      Casado   Feminino
# 3             175     31           Sim      Casado   Feminino
# 4             328     33           Sim      Casado   Feminino
# 5             445     39           Sim      Casado   Feminino
# 6             684     45           Sim      Casado   Feminino
# 7             840     49           Sim      Casado   Feminino
# 8            1033     37           Sim      Casado   Feminino
# 9            1038     52           Sim      Casado   Feminino
# 10           1295     44           Sim      Casado   Feminino
# 11           1360     58           Sim      Casado   Feminino
# 12           1380     35           Sim      Casado   Feminino
# 13           1467     34           Sim      Casado   Feminino
# ...

# %%
#Atribuindo valor à nova coluna - exemplo
base_filtrada['coluna_nova'] = 0
# Out:
# <ipython-input-40-8bf98bcc90c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_filtrada['coluna_nova'] = 0

# %%
base_filtrada
# Out:
#     IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0              58     10           Sim      Casado   Feminino
# 1             161     10           Sim      Casado   Feminino
# 2             165     10           Sim      Casado   Feminino
# 3             175     10           Sim      Casado   Feminino
# 4             328     10           Sim      Casado   Feminino
# 5             445     10           Sim      Casado   Feminino
# 6             684     10           Sim      Casado   Feminino
# 7             840     10           Sim      Casado   Feminino
# 8            1033     10           Sim      Casado   Feminino
# 9            1038     10           Sim      Casado   Feminino
# 10           1295     10           Sim      Casado   Feminino
# 11           1360     10           Sim      Casado   Feminino
# 12           1380     10           Sim      Casado   Feminino
# 13           1467     10           Sim      Casado   Feminino
# ...
