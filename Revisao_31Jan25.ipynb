# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardoefamilia/CollectionsSet/blob/master/Revisao_31Jan25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import sklearn

# %%
##Copiando nova base de dados
base_energia_sola = pd.read_csv("/content/previsao_energia_solar.csv")

# %%
base_energia_sola
# Out:
#        Localizacao      Data  Mes  Hora  Estacao   Umidade Temperatura  \
# 0                0  20171203   12    11        0  81,71997    12,86919
# 1                0  20171203   12    13        0  96,64917     9,66415
# 2                0  20171203   12    13        0  93,61572    15,44983
# 3                0  20171204   12    12        0  77,21558    10,36659
# 4                0  20171204   12    14        0  54,80347    16,85471
# ...            ...       ...  ...   ...      ...       ...         ...
# 21040           11  20180928    9    15        3  11,66992     43,2251
# 21041           11  20180929    9    13        3   18,2251    28,98247
# 21042           11  20180929    9    14        3  15,52124    33,49167
# 21043           11  20180929    9    15        3   6,63452    51,62163
# 21044           11  20181001   10    14        3  22,58301    32,83958
#
#         Geracao  Vento Visibilidade Pressao  Cloud.Ceiling
# ...
